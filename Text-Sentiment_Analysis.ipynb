# %%
# path=r'C:\Users\Dell\Downloads\txt_reviews.zip'

# %% [markdown]
# ## Extracting the zip files

# %%
#  from zipfile import ZipFile
#  with ZipFile(path, 'r') as zipObj:
#      Extract all the contents of zip file in current directory
#      zipObj.extractall(r'E:\files')

# %%
# ProductId = []
# UserId = []
# ProfileName = []
# HelpfulnessNumerator = []
# HelpfulnessDenominator = []
# Score = []
# Time = []
# ReviewSummary = []
# ReviewText = []

# for i in range(1,568455):
#     text = open(fr'E:\files\txt_reviews\review_{i}.txt', encoding='utf-8')
#     ls = text.read()
#     splt_ls = ls.split("\n")[0]
#     ProductId.append(splt_ls.split(":")[1])

#     splt_ls = ls.split("\n")[1]
#     UserId.append(splt_ls.split(":")[1])

#     splt_ls = ls.split("\n")[2]
#     ProfileName.append(splt_ls.split(":")[1])

#     splt_ls = ls.split("\n")[3]
#     HelpfulnessNumerator.append(splt_ls.split(":")[1])

#     splt_ls = ls.split("\n")[4]
#     HelpfulnessDenominator.append(splt_ls.split(":")[1])

#     splt_ls = ls.split("\n")[5]
#     Score.append(splt_ls.split(":")[1])

#     splt_ls = ls.split("\n")[6]
#     Time.append(splt_ls.split(":")[1])

#     splt_ls = ls.split("\n")[7]
#     ReviewSummary.append(splt_ls.split(":")[1])

#     splt_ls = ls.split("\n")[8]
#     ReviewText.append(splt_ls.split(":")[1])

# %%
# import pandas as pd

# %% [markdown]
# ## Creating the dataframe

# %%
# df=pd.DataFrame({'ProductId':ProductId,'UserId':UserId,'ProfileName':ProfileName,'HelpfulnessNumerator':HelpfulnessNumerator,
# 'HelpfulnessDenominator':HelpfulnessDenominator,
# 'Score':Score,
# 'Time':Time,
# 'ReviewSummary':ReviewSummary,
# # 'ReviewText':ReviewText})
# df.head()
# Out:
#      ProductId           UserId                       ProfileName  \
# 0   B001E4KFG0   A3SGXH7AUHU8GW                        delmartian
# 1   B00813GRG4   A1D87F6ZCVE5NK                            dll pa
# 2   B000LQOCH0    ABXLMWJIXXAIN   Natalia Corres "Natalia Corres"
# 3   B000UA0QIQ   A395BORC6FGVXV                              Karl
# 4   B006K2ZZ7K   A1UQRSCLF8GW1T     Michael D. Bigham "M. Wassir"
#
#   HelpfulnessNumerator HelpfulnessDenominator Score         Time  \
# 0                    1                      1     5   1303862400
# 1                    0                      0     1   1346976000
# 2                    1                      1     4   1219017600
# 3                    3                      3     2   1307923200
# 4                    0                      0     5   1350777600
#
#             ReviewSummary                                         ReviewText
# 0   Good Quality Dog Food   I have bought several of the Vitality canned ...
# ...

# %%
# df.shape
# Out:
# (568454, 9)

# %%
# id=[]
# for i in range(1,df.shape[0]+1):
#     id.append(i)

# %%
# df.head()
# Out:
#    Id    ProductId           UserId                       ProfileName  \
# 0   1   B001E4KFG0   A3SGXH7AUHU8GW                        delmartian
# 1   2   B00813GRG4   A1D87F6ZCVE5NK                            dll pa
# 2   3   B000LQOCH0    ABXLMWJIXXAIN   Natalia Corres "Natalia Corres"
# 3   4   B000UA0QIQ   A395BORC6FGVXV                              Karl
# 4   5   B006K2ZZ7K   A1UQRSCLF8GW1T     Michael D. Bigham "M. Wassir"
#
#   HelpfulnessNumerator HelpfulnessDenominator Score         Time  \
# 0                    1                      1     5   1303862400
# 1                    0                      0     1   1346976000
# 2                    1                      1     4   1219017600
# 3                    3                      3     2   1307923200
# 4                    0                      0     5   1350777600
#
#             ReviewSummary                                         ReviewText
# ...

# %% [markdown]
# ## Saving the dataframe to csv file

# %%
# df.to_csv('txt_review.csv')

# %%
import pandas as pd

# %%
path=r'C:\Users\Dell\Downloads\txt_review.csv'

# %% [markdown]
# ## load the data

# %%
df=pd.read_csv(path)

# %%
df.head()
# Out:
#    Unnamed: 0  Id    ProductId           UserId  \
# 0           0   1   B001E4KFG0   A3SGXH7AUHU8GW
# 1           1   2   B00813GRG4   A1D87F6ZCVE5NK
# 2           2   3   B000LQOCH0    ABXLMWJIXXAIN
# 3           3   4   B000UA0QIQ   A395BORC6FGVXV
# 4           4   5   B006K2ZZ7K   A1UQRSCLF8GW1T
#
#                         ProfileName  HelpfulnessNumerator  \
# 0                        delmartian                     1
# 1                            dll pa                     0
# 2   Natalia Corres "Natalia Corres"                     1
# 3                              Karl                     3
# 4     Michael D. Bigham "M. Wassir"                     0
#
#    HelpfulnessDenominator  Score        Time           ReviewSummary  \
# 0                       1      5  1303862400   Good Quality Dog Food
# 1                       0      1  1346976000       Not as Advertised
# 2                       1      4  1219017600   "Delight" says it all
# ...

# %% [markdown]
# ## Data Analysis

# %%
df=df.drop('Unnamed: 0', axis=1)

# %%
df['Score'].value_counts()
# Out:
# 5    363122
# 4     80655
# 1     52268
# 3     42640
# 2     29769
# Name: Score, dtype: int64

# %%
import seaborn as sns
sns.countplot(x='Score',data=df)
# Out:
# <Axes: xlabel='Score', ylabel='count'>

# %%
df.columns
# Out:
# Index(['Id', 'ProductId', 'UserId', 'ProfileName', 'HelpfulnessNumerator',
#        'HelpfulnessDenominator', 'Score', 'Time', 'ReviewSummary',
#        'ReviewText'],
#       dtype='object')

# %%
df['review_text'] = df['ReviewSummary'] + " " + df['ReviewText']

# %%
df=df[df['Score']!=3]

# %%
# Create a mapping dictionary for sentiment labels
sentiment_mapping = {
    1: 'Negative',
    2: 'Negative',
    4: 'Positive',
    5: 'Positive'
}

# Convert numerical values in score to sentiment labels
df['Sentiment'] =df['Score'].map(sentiment_mapping)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_11436\2773603905.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Sentiment'] =df['Score'].map(sentiment_mapping)

# %%
df.head()
# Out:
#    Id    ProductId           UserId                       ProfileName  \
# 0   1   B001E4KFG0   A3SGXH7AUHU8GW                        delmartian
# 1   2   B00813GRG4   A1D87F6ZCVE5NK                            dll pa
# 2   3   B000LQOCH0    ABXLMWJIXXAIN   Natalia Corres "Natalia Corres"
# 3   4   B000UA0QIQ   A395BORC6FGVXV                              Karl
# 4   5   B006K2ZZ7K   A1UQRSCLF8GW1T     Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#             ReviewSummary                                         ReviewText  \
# ...

# %%
from wordcloud import WordCloud

# %%
#creating a dataframe for positive sentiments
df_positive=df.loc[df["Sentiment"]=="Positive",:]

#joining the positive sentences 
words=" ".join(df_positive["review_text"]).lower()

#cleaned words

cleaned_words=" ".join([word for word in words.split() if word not in ["love","like","great","taste","really","good","best","br"]]) 
positive_wordcloud = WordCloud(stopwords=stopwords.words("english"),
                      background_color='black',
                      width=1600,
                      height=800
                     ).generate(cleaned_words) 
plt.figure(1,figsize=(30,20))
plt.imshow(positive_wordcloud)
plt.axis('off')
plt.show()

# %%
#creating a dataframe for negative sentiments
df_negative=df.loc[df["Sentiment"]=="Negative",:]

#joining the negative sentences 
words=" ".join(df_negative["review_text"]).lower()

#cleaned words

cleaned_words=" ".join([word for word in words.split() if word not in ["hate","bad","worst","really","br"]]) 
negative_wordcloud = WordCloud(stopwords=stopwords.words("english"),
                      background_color='black',
                      width=1600,
                      height=800
                     ).generate(cleaned_words) 
plt.figure(1,figsize=(30,20))
plt.imshow(negative_wordcloud)
plt.axis('off')
plt.show()

# %%
# splitting input and output variables
X=df[['review_text']]
y=df['Sentiment']

# %% [markdown]
# ## Splitting the data- train-test-split

# %%
# Splitting into train and test

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=45)

# %%
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
stemmer=PorterStemmer()

# %%
lemmatizer=WordNetLemmatizer()

# %% [markdown]
# ## Text Cleaning

# %%
# Define preprocess function
def preprocess(text, flag):
    # remove special characters
    sentence = re.sub(r'[^a-zA-Z]', ' ', text)
    # convert sentence into lower case
    sentence = sentence.lower()
    # tokenize sentence into words
    tokens = sentence.split()
    # remove stop words
    clean_tokens = [token for token in tokens if token not in stopwords.words("english")]
    # stemming/lemmatization
    if flag == 'stem':
        clean_tokens = [stemmer.stem(token) for token in clean_tokens]
    else:
        clean_tokens = [lemmatizer.lemmatize(token) for token in clean_tokens]
    return pd.Series(' '.join(clean_tokens))

# %%
X_train.head()
# Out:
#                                               review_text
# 568253   Very good stevia without any extra ingredient...
# 365733   Best granola I ever ate.  I tried just about ...
# 80260    Weird aftertaste..  This was the first k-cup ...
# 258312   Good price  The price at amazon varies for th...
# 493252   Wonderfully yummy  I was intrigued how this p...

# %%
from tqdm import tqdm, tqdm_notebook
# Register `pandas.progress_apply` and `pandas.Series.map_apply` with `tqdm`

tqdm.pandas()

# %%
# Apply preprocess function to 'review_text' column in DataFrame
X_train_transformed= X_train['review_text'].progress_apply(lambda x: preprocess(x, flag='lemma'))

# Display the updated DataFrame
X_train_transformed.head()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 394360/394360 [14:40:47<00:00,  7.46it/s]
#                                                         0
# 568253  good stevia without extra ingredient bought sh...
# 365733  best granola ever ate tried every granola amza...
# 80260   weird aftertaste first k cup tried keurig coff...
# 258312  good price price amazon varies product competi...
# 493252  wonderfully yummy intrigued particular blend g...

# %%
X_train_transformed.columns = ['clean_review_text']

X_train_transformed.head()
# Out:
#                                         clean_review_text
# 568253  good stevia without extra ingredient bought sh...
# 365733  best granola ever ate tried every granola amza...
# 80260   weird aftertaste first k cup tried keurig coff...
# 258312  good price price amazon varies product competi...
# 493252  wonderfully yummy intrigued particular blend g...

# %%
X_train_transformed.to_csv('X_train_transformed.csv')

# %% [markdown]
# ## Converting Text to Numerical vectors - BOW Representation

# %%
# Text transformation using Bag of words
from sklearn.feature_extraction.text import CountVectorizer

vocab = CountVectorizer()

X_train_bow = vocab.fit_transform(X_train_transformed['clean_review_text'])

# %%
print("Total unique words:", len(vocab.vocabulary_))

print("Type of train features:", type(X_train_bow))

print("Shape of input data:", X_train_bow.shape)
# Out:
# Total unique words: 82810
# Type of train features: <class 'scipy.sparse._csr.csr_matrix'>
# Shape of input data: (394360, 82810)

# %%
from sys import getsizeof

print(type(X_train_bow))
print(getsizeof(X_train_bow), "Bytes")
# Out:
# <class 'scipy.sparse._csr.csr_matrix'>
# 48 Bytes

# %% [markdown]
# ## Preprocessing on Test data

# %%
X_test.head()
# Out:
#                                               review_text
# 514903   Very Convenient  Love Jack Links, so I was th...
# 46499    good product  The is a great product if you a...
# 160852   Great value  I have been enjoying Kookaburra ...
# 191938   Kids voted this a delicious snack  I put thes...
# 406533   Best bread  These packets of bread kits are s...

# %%
X_test_transformed= X_test['review_text'].progress_apply(lambda x: preprocess(x, flag='lemma'))

# Display the updated DataFrame
X_test_transformed.head()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 131454/131454 [46:38<00:00, 46.97it/s]
#                                                         0
# 514903  convenient love jack link thrilled see easy gr...
# 46499   good product great product weight watcher two ...
# 160852  great value enjoying kookaburra black licorice...
# 191938  kid voted delicious snack put kid school lunch...
# 406533  best bread packet bread kit quick easy fresh f...

# %%
X_test_transformed.columns = ['clean_review_text']

X_test_transformed.head()
# Out:
#                                         clean_review_text
# 514903  convenient love jack link thrilled see easy gr...
# 46499   good product great product weight watcher two ...
# 160852  great value enjoying kookaburra black licorice...
# 191938  kid voted delicious snack put kid school lunch...
# 406533  best bread packet bread kit quick easy fresh f...

# %%
X_test_transformed.to_csv('X_test_transformed.csv')

# %%
X_test_bow = vocab.transform(X_test_transformed['clean_review_text'])

# %%
X_test_bow.shape
# Out:
# (131454, 82810)

# %% [markdown]
# ## Model Building

# %% [markdown]
# ## KNN Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_model=KNeighborsClassifier()
knn_model.fit(X_train_bow,y_train)
# Out:
# KNeighborsClassifier()

# %%
import sys

# %%
knn_model_size_bow = sys.getsizeof(knn_model)
print("The size of the knn_model is: ",knn_model_size_bow,"Bytes")
# Out:
# The size of the knn_model is:  48 Bytes

# %%
# prediction
y_test_pred = knn_model.predict(X_test_bow)

# %%
from sklearn.metrics import accuracy_score

# %%
# evaluation
knn_model_bow_accuracy=accuracy_score(y_test, y_test_pred)
print("Accuracy of knn classifier model is: ",knn_model_bow_accuracy)
# Out:
# Accuracy of knn classifier model is:  0.8896800401661418

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
logistic_reg_model = LogisticRegression()
logistic_reg_model.fit(X_train_bow, y_train)
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
logistic_reg_model_size_bow = sys.getsizeof(logistic_reg_model)
print("The size of the logistic_reg_model is: ",logistic_reg_model_size_bow,"Bytes")
# Out:
# The size of the logistic_reg_model is:  48 Bytes

# %%
import time

# %%
# Capture the start time
start_time = time.time()
# prediction
y_test_pred = logistic_reg_model.predict(X_test_bow)
# Capture the end time
end_time = time.time()

# Calculate the prediction time
prediction_time = end_time - start_time

print(f"Prediction time: {prediction_time:.6f} seconds")
# Out:
# Prediction time: 0.054189 seconds

# %%
# evaluation
logistic_reg_model_bow_accuracy=accuracy_score(y_test, y_test_pred)
print("Accuracy of logistic regression classifier model is: ",logistic_reg_model_bow_accuracy)
# Out:
# Accuracy of logistic regression classifier model is:  0.9468863632905807

# %% [markdown]
# ## Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
decision_tree_model = DecisionTreeClassifier()
decision_tree_model.fit(X_train_bow, y_train)
# Out:
# DecisionTreeClassifier()

# %%
decision_tree_model_size_bow = sys.getsizeof(decision_tree_model)
print("The size of the decision_tree_model is: ",decision_tree_model_size_bow,"Bytes")
# Out:
# The size of the decision_tree_model is:  48 Bytes

# %%
# Capture the start time
start_time = time.time()
# prediction
y_test_pred = decision_tree_model.predict(X_test_bow)
# Capture the end time
end_time = time.time()

# Calculate the prediction time
prediction_time = end_time - start_time

print(f"Prediction time: {prediction_time:.6f} seconds")
# Out:
# Prediction time: 0.200557 seconds

# %%
# evaluation
decision_tree_model_bow_accuracy=accuracy_score(y_test, y_test_pred)
print("Accuracy of decision tree classifier model is: ",decision_tree_model_bow_accuracy)
# Out:
# Accuracy of decision tree classifier model is:  0.9222237436669861

# %% [markdown]
# ## Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
random_forest_model = RandomForestClassifier()
random_forest_model.fit(X_train_bow, y_train)
# Out:
# RandomForestClassifier()

# %%
# Get the size of the model in memory
random_forest_model_size_bow = sys.getsizeof(random_forest_model)
print("The size of the random_forest_model is: ",random_forest_model_size_bow,"Bytes")
# Out:
# The size of the random_forest_model is:  48 Bytes

# %%
# Capture the start time
start_time = time.time()
# prediction
y_test_pred = random_forest_model.predict(X_test_bow)
# Capture the end time
end_time = time.time()

# Calculate the prediction time
prediction_time = end_time - start_time

print(f"Prediction time: {prediction_time:.6f} seconds")
# Out:
# Prediction time: 34.322906 seconds

# %%
# evaluation
random_forest_model_bow_accuracy=accuracy_score(y_test, y_test_pred)
print("Accuracy of Random Forest classifier model is: ",random_forest_model_bow_accuracy)
# Out:
# Accuracy of Random Forest classifier model is:  0.9362362499429459

# %% [markdown]
# ## Preprocessing using tf-idf

# %%
# TF-IDF

from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()

X_train_dtm = vectorizer.fit_transform(X_train_transformed['clean_review_text'])

# %%
print(X_train_dtm)
# Out:
#   (0, 75743)	0.08742218649462999
#   (0, 2181)	0.07418031916219062
#   (0, 9839)	0.07402889163151716
#   (0, 53683)	0.19348357530504393
#   (0, 43549)	0.25592087493344107
#   (0, 14314)	0.16733256270388183
#   (0, 14039)	0.19332457856620014
#   (0, 70929)	0.16567899517233511
#   (0, 56961)	0.058516316012232054
#   (0, 41757)	0.051545146177335334
#   (0, 57966)	0.5902130796945074
#   (0, 75335)	0.39950027601844457
#   (0, 71380)	0.1915691619828335
#   (0, 14768)	0.12667339351527043
#   (0, 73325)	0.0863005939620554
#   (0, 71333)	0.08607426098243603
#   (0, 23854)	0.09692825265878817
#   (0, 32944)	0.09656236943389532
#   (0, 64515)	0.13394469646504373
#   (0, 12142)	0.11239623774667544
#   (0, 8454)	0.08555939045804267
#   (0, 65542)	0.24675861463970786
#   (0, 8356)	0.0839189614931878
#   (0, 36812)	0.1877987124910004
#   (0, 25639)	0.11177178854508563
#   :	:
#   (394358, 62695)	0.38250493451071016
#   (394358, 9387)	0.29353753808980393
#   (394358, 7753)	0.24237379609422444
# ...

# %%
X_test_dtm=vectorizer.transform(X_test_transformed['clean_review_text'])

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
logistic_reg_model_tf_idf = LogisticRegression()
logistic_reg_model_tf_idf.fit(X_train_dtm, y_train)
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
logistic_reg_model_size_tf_idf = sys.getsizeof(logistic_reg_model_tf_idf)
print("The size of the logistic_reg_model is: ",logistic_reg_model_size_tf_idf,'Bytes')
# Out:
# The size of the logistic_reg_model is:  48 Bytes

# %%
# Capture the start time
start_time = time.time()
# prediction
y_test_pred = logistic_reg_model_tf_idf.predict(X_test_dtm)
# Capture the end time
end_time = time.time()

# Calculate the prediction time
prediction_time = end_time - start_time

print(f"Prediction time: {prediction_time:.6f} seconds")
# Out:
# Prediction time: 0.022937 seconds

# %%
# evaluation
logistic_reg_model_tf_idf_accuracy=accuracy_score(y_test, y_test_pred)
print("Accuracy of logistic regression classifier model is: ",logistic_reg_model_tf_idf_accuracy)
# Out:
# Accuracy of logistic regression classifier model is:  0.944429229996805

# %% [markdown]
# ## Decision Tree

# %%
decision_tree_model_tf_idf = DecisionTreeClassifier()
decision_tree_model_tf_idf.fit(X_train_dtm,y_train)
# Out:
# DecisionTreeClassifier()

# %%
decision_tree_model_size_tf_idf = sys.getsizeof(decision_tree_model_tf_idf)
print("The size of the decision_tree_model is: ",decision_tree_model_size_tf_idf)
# Out:
# The size of the decision_tree_model is:  48

# %%
# Capture the start time
start_time = time.time()
# prediction
y_test_pred = decision_tree_model_tf_idf.predict(X_test_dtm)
# Capture the end time
end_time = time.time()

# Calculate the prediction time
prediction_time = end_time - start_time

print(f"Prediction time: {prediction_time:.6f} seconds")
# Out:
# Prediction time: 0.521668 seconds

# %%
# evaluation
decision_tree_model_tf_idf_accuracy=accuracy_score(y_test, y_test_pred)
print("Accuracy of decision tree classifier model is: ",decision_tree_model_tf_idf_accuracy)
# Out:
# Accuracy of decision tree classifier model is:  0.9183212378474599

# %% [markdown]
# ## Random Forest

# %%
random_forest_model_tf_idf = RandomForestClassifier()
random_forest_model_tf_idf.fit(X_train_dtm,y_train)
# Out:
# RandomForestClassifier()

# %%
# Get the size of the model in memory
random_forest_model_size_tf_idf = sys.getsizeof(random_forest_model_tf_idf)
print("The size of the random_forest_model is: ",random_forest_model_size_tf_idf)
# Out:
# The size of the random_forest_model is:  48

# %%
# Capture the start time
start_time = time.time()
# prediction
y_test_pred = random_forest_model_tf_idf.predict(X_test_dtm)
# Capture the end time
end_time = time.time()

# Calculate the prediction time
prediction_time = end_time - start_time

print(f"Prediction time: {prediction_time:.6f} seconds")
# Out:
# Prediction time: 23.467889 seconds

# %%
# evaluation
random_forest_model_tf_idf_accuracy=accuracy_score(y_test, y_test_pred)
print("Accuracy of Random Forest classifier model is: ",random_forest_model_tf_idf_accuracy)
# Out:
# Accuracy of Random Forest classifier model is:  0.9340529767066806

# %% [markdown]
# ## Comparision of model accuracies

# %%
# using Bag of words:
data = {
    'Model Name': ['KNN Classifier', 'Logistic Regression', 'Decision Tree Classifier', 'Random Forest Classifier'],
    'Accuracy': [0.8896800401661418, 0.9468863632905807, 0.9222237436669861, 0.9362362499429459]
}

bow_df = pd.DataFrame(data)
bow_df['Accuracy'] = bow_df['Accuracy'] * 100
bow_df.head()
# Out:
#                  Model Name   Accuracy
# 0            KNN Classifier  88.968004
# 1       Logistic Regression  94.688636
# 2  Decision Tree Classifier  92.222374
# 3  Random Forest Classifier  93.623625

# %%
import matplotlib.pyplot as plt

# %%
# Create the bar plot
plt.figure(figsize=(10, 6))
bars=plt.barh(bow_df['Model Name'], bow_df['Accuracy'])
plt.ylabel('Model Name')
plt.xlabel('Accuracy (%)')
plt.title('Model Accuracies preprocessed using Bag of words')

for bar in bars:
    width = bar.get_width()
    plt.gca().text(bar.get_width() - 5, bar.get_y() + bar.get_height() / 2,
                   f'{width:.1f}', ha='right', va='center', color='white')
plt.tight_layout()

# Show the plot
plt.show()

# %%
# using tf-idf:
data = {
    'Model Name': ['Logistic Regression', 'Decision Tree Classifier', 'Random Forest Classifier'],
    'Accuracy': [0.944429229996805,0.9183212378474599,0.9340529767066806]
}

tf_idf_df = pd.DataFrame(data)
tf_idf_df['Accuracy'] = tf_idf_df['Accuracy'] * 100
tf_idf_df.head()
# Out:
#                  Model Name   Accuracy
# 0       Logistic Regression  94.442923
# 1  Decision Tree Classifier  91.832124
# 2  Random Forest Classifier  93.405298

# %%
# Create the bar plot
plt.figure(figsize=(10, 6))
bars=plt.barh(tf_idf_df['Model Name'], tf_idf_df['Accuracy'])
plt.ylabel('Model Name')
plt.xlabel('Accuracy (%)')
plt.title('Model Accuracies preprocessed using TF_IDF')

for bar in bars:
    width = bar.get_width()
    plt.gca().text(bar.get_width() - 5, bar.get_y() + bar.get_height() / 2,
                   f'{width:.1f}', ha='right', va='center', color='white')
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Conclusion:

# %% [markdown]
# * It can be observed that, The accuracies of the models is similar using both the preprocessing techniques.
# * The Logistic Regression has the highest accuracy of 94.7% comapared to the other models.
# * The Logistic Regression model has the least prediction time and the size of the model is also less compared to the other models.
# * Hence, The Logistic Regression model is the best suitable model for the text sentiment analysis.

# %%
import pickle

# %%
filename1="lr_model.sav"
pickle.dump(logistic_reg_model,open(filename1,'wb'))

# %%
loaded_model_lr=pickle.load(open('lr_model.sav','rb'))

# %%
filename2="count_vectorizer.sav"
pickle.dump(vocab,open(filename2,'wb'))

# %%
loaded_vec_cv=pickle.load(open('count_vectorizer.sav','rb'))
